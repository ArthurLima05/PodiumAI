# %%
import pandas as pd

drivers = pd.read_csv('../data/drivers.csv')
races = pd.read_csv('../data/races.csv')
results = pd.read_csv('../data/results.csv')
circuits = pd.read_csv('../data/circuits.csv')
status = pd.read_csv('../data/status.csv')
constructors = pd.read_csv('../data/constructors.csv')


constructors_renamed = constructors.rename(columns={'name': 'constructorName'})

df = (
    results
    .merge(drivers, on='driverId')
    .merge(races, on='raceId')
    .merge(circuits, on='circuitId')
    .merge(status[['statusId', 'status']], on='statusId')
    .merge(constructors_renamed[['constructorId', 'constructorName', 'constructorRef', 'nationality']], on='constructorId')
)

# %%
df.head()
# Out:
#    resultId  raceId  driverId  constructorId number_x  grid position  \
# 0         1      18         1              1       22     1        1
# 1         2      18         2              2        3     5        2
# 2         3      18         3              3        7     7        3
# 3         4      18         4              4        5    11        4
# 4         5      18         5              1       23     3        5
#
#   positionText  positionOrder  points  ...   location    country      lat  \
# 0            1              1    10.0  ...  Melbourne  Australia -37.8497
# 1            2              2     8.0  ...  Melbourne  Australia -37.8497
# 2            3              3     6.0  ...  Melbourne  Australia -37.8497
# 3            4              4     5.0  ...  Melbourne  Australia -37.8497
# 4            5              5     4.0  ...  Melbourne  Australia -37.8497
#
#        lng alt                                                url    status  \
# 0  144.968  10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...  Finished
# 1  144.968  10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...  Finished
# 2  144.968  10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...  Finished
# 3  144.968  10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...  Finished
# 4  144.968  10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...  Finished
#
#    constructorName constructorRef nationality_y
# 0          McLaren        mclaren       British
# 1       BMW Sauber     bmw_sauber        German
# 2         Williams       williams       British
# 3          Renault        renault        French
# 4          McLaren        mclaren       British
#
# [5 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26759 entries, 0 to 26758
# Data columns (total 55 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resultId         26759 non-null  int64
#  1   raceId           26759 non-null  int64
#  2   driverId         26759 non-null  int64
#  3   constructorId    26759 non-null  int64
#  4   number_x         26759 non-null  object
#  5   grid             26759 non-null  int64
#  6   position         26759 non-null  object
#  7   positionText     26759 non-null  object
#  8   positionOrder    26759 non-null  int64
#  9   points           26759 non-null  float64
#  10  laps             26759 non-null  int64
#  11  time_x           26759 non-null  object
#  12  milliseconds     26759 non-null  object
#  13  fastestLap       26759 non-null  object
#  14  rank             26759 non-null  object
#  15  fastestLapTime   26759 non-null  object
#  16  fastestLapSpeed  26759 non-null  object
#  17  statusId         26759 non-null  int64
#  18  driverRef        26759 non-null  object
#  19  number_y         26759 non-null  object
#  20  code             26759 non-null  object
#  21  forename         26759 non-null  object
#  22  surname          26759 non-null  object
#  23  dob              26759 non-null  object
#  24  nationality_x    26759 non-null  object
#  25  url_x            26759 non-null  object
#  26  year             26759 non-null  int64
#  27  round            26759 non-null  int64
#  28  circuitId        26759 non-null  int64
#  29  name_x           26759 non-null  object
#  30  date             26759 non-null  object
#  31  time_y           26759 non-null  object
#  32  url_y            26759 non-null  object
#  33  fp1_date         26759 non-null  object
#  34  fp1_time         26759 non-null  object
#  35  fp2_date         26759 non-null  object
#  36  fp2_time         26759 non-null  object
#  37  fp3_date         26759 non-null  object
#  38  fp3_time         26759 non-null  object
#  39  quali_date       26759 non-null  object
#  40  quali_time       26759 non-null  object
#  41  sprint_date      26759 non-null  object
#  42  sprint_time      26759 non-null  object
#  43  circuitRef       26759 non-null  object
#  44  name_y           26759 non-null  object
#  45  location         26759 non-null  object
#  46  country          26759 non-null  object
#  47  lat              26759 non-null  float64
#  48  lng              26759 non-null  float64
#  49  alt              26759 non-null  int64
#  50  url              26759 non-null  object
#  51  status           26759 non-null  object
#  52  constructorName  26759 non-null  object
#  53  constructorRef   26759 non-null  object
#  54  nationality_y    26759 non-null  object
# dtypes: float64(3), int64(12), object(40)
# memory usage: 11.2+ MB
